# %% [markdown]
# <a href="https://colab.research.google.com/github/arze04/PSMDSRC103_SY20252026A/blob/main/Taxi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercise 1.1 Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
import pandas as pd

taxi= pd.read_csv('/content/2019_Yellow_Taxi_Trip_Data.csv', nrows=5)
taxi.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5      1      0.5
# ...

# %%
# Exercise 1.2 Find the dimensions (number of rows and number of columns) in the data.

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendorid               5 non-null      int64
#  1   tpep_pickup_datetime   5 non-null      object
#  2   tpep_dropoff_datetime  5 non-null      object
#  3   passenger_count        5 non-null      int64
#  4   trip_distance          5 non-null      float64
#  5   ratecodeid             5 non-null      int64
#  6   store_and_fwd_flag     5 non-null      object
#  7   pulocationid           5 non-null      int64
#  8   dolocationid           5 non-null      int64
#  9   payment_type           5 non-null      int64
#  10  fare_amount            5 non-null      float64
#  11  extra                  5 non-null      int64
#  12  mta_tax                5 non-null      float64
#  13  tip_amount             5 non-null      float64
# ...

# %% [markdown]
# Number of rows is 5
# Number of columns is 18

# %%
# Exercise 1.3 Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.

# %%
import pandas as pd

taxi= pd.read_csv('/content/2019_Yellow_Taxi_Trip_Data (1).csv', nrows=5)
taxi
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5      1      0.5
# ...

# %%
taxi[['fare_amount','tip_amount','tolls_amount','total_amount']].describe()
# Out:
#        fare_amount  tip_amount  tolls_amount  total_amount
# count     5.000000    5.000000      5.000000       5.00000
# mean     14.600000    2.960000      1.224000      22.58400
# std       8.429116    3.270505      2.736947      14.54879
# min       9.500000    0.000000      0.000000      12.30000
# 25%      10.500000    0.500000      0.000000      15.30000
# 50%      10.500000    2.000000      0.000000      15.80000
# 75%      13.000000    4.320000      0.000000      21.62000
# max      29.500000    7.980000      6.120000      47.90000

# %%
# Exercise 1.4 Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
longest_trip_index = taxi['trip_distance'].idxmax()

# %%
longest_trip = taxi.loc[longest_trip_index, ['fare_amount', 'tip_amount', 'tolls_amount', 'total_amount']]
longest_trip.head()
# Out:
# fare_amount     29.5
# tip_amount      7.98
# tolls_amount    6.12
# total_amount    47.9
# Name: 0, dtype: object
